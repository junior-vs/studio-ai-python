# %% [markdown]
# ***
# # <font color=green size=10>CURSO DE ESTATÍSTICA - PARTE 1</font>
# ***

# %% [markdown]
# # <font color=green>1 CONHECENDO OS DADOS</font>
# ***

# %% [markdown]
# ## <font color=green>1.1 Dataset do projeto</font>
# ***

# %% [markdown]
# ### Pesquisa Nacional por Amostra de Domicílios - 2015
#
# A <b>Pesquisa Nacional por Amostra de Domicílios - PNAD</b> investiga anualmente, de forma permanente, características gerais da população, de educação, trabalho, rendimento e habitação e outras, com periodicidade variável, de acordo com as necessidades de informação para o país, como as características sobre migração, fecundidade, nupcialidade, saúde, segurança alimentar, entre outros temas. O levantamento dessas estatísticas constitui, ao longo dos 49 anos de realização da pesquisa, um importante instrumento para formulação, validação e avaliação de políticas orientadas para o desenvolvimento socioeconômico e a melhoria das condições de vida no Brasil.

# %% [markdown]
# ### Fonte dos Dados
#
# https://ww2.ibge.gov.br/home/estatistica/populacao/trabalhoerendimento/pnad2015/microdados.shtm

# %%
# %pip install pandas numpy seaborn scipy matplotlib
# Out:
# Collecting pandas
#   Using cached pandas-2.3.1-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy
#   Using cached numpy-2.3.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting scipy
#   Using cached scipy-1.16.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.10.3-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\desenvolvimento\repo\studios\studio-ia-python\course\formacao-data-science-python\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.2-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.59.0-cp312-cp312-win_amd64.whl.metadata (110 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in c:\desenvolvimento\repo\studios\studio-ia-python\course\formacao-data-science-python\.venv\lib\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-11.3.0-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: six>=1.5 in c:\desenvolvimento\repo\studios\studio-ia-python\course\formacao-data-science-python\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.3.1-cp312-cp312-win_amd64.whl (11.0 MB)
# Using cached numpy-2.3.1-cp312-cp312-win_amd64.whl (12.7 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached scipy-1.16.0-cp312-cp312-win_amd64.whl (38.4 MB)
# Using cached matplotlib-3.10.3-cp312-cp312-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.2-cp312-cp312-win_amd64.whl (223 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.59.0-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Using cached pillow-11.3.0-cp312-cp312-win_amd64.whl (7.0 MB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, scipy, pandas, contourpy, matplotlib, seaborn
#
#    ----------------------------------------  0/13 [pytz]
#    ----------------------------------------  0/13 [pytz]
#    ----------------------------------------  0/13 [pytz]
#    ----------------------------------------  0/13 [pytz]
#    ----------------------------------------  0/13 [pytz]
#    ----------------------------------------  0/13 [pytz]
#    --- ------------------------------------  1/13 [tzdata]
#    --- ------------------------------------  1/13 [tzdata]
#    --- ------------------------------------  1/13 [tzdata]
#    --- ------------------------------------  1/13 [tzdata]
#    ------ ---------------------------------  2/13 [pyparsing]
#    ------ ---------------------------------  2/13 [pyparsing]
#    ------ ---------------------------------  2/13 [pyparsing]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    --------- ------------------------------  3/13 [pillow]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    ------------ ---------------------------  4/13 [numpy]
#    --------------- ------------------------  5/13 [kiwisolver]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------ ---------------------  6/13 [fonttools]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    ------------------------ ---------------  8/13 [scipy]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    --------------------------- ------------  9/13 [pandas]
#    ------------------------------ --------- 10/13 [contourpy]
#    ------------------------------ --------- 10/13 [contourpy]
#    ------------------------------ --------- 10/13 [contourpy]
#    ------------------------------ --------- 10/13 [contourpy]
#    ------------------------------ --------- 10/13 [contourpy]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ---------------------------------------- 13/13 [seaborn]
#
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.59.0 kiwisolver-1.4.8 matplotlib-3.10.3 numpy-2.3.1 pandas-2.3.1 pillow-11.3.0 pyparsing-3.2.3 pytz-2025.2 scipy-1.16.0 seaborn-0.13.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy as sp
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# ### Variáveis utilizadas
#
# > ### Renda
# > ***
#
# Rendimento mensal do trabalho principal para pessoas de 10 anos ou mais de idade.
#
# > ### Idade
# > ***
#
# Idade do morador na data de referência em anos.
#
# > ### Altura (elaboração própria)
# > ***
#
# Altura do morador em metros.
#
# > ### UF
# > ***
#
# |Código|Descrição|
# |---|---|
# |11|Rondônia|
# |12|Acre|
# |13|Amazonas|
# |14|Roraima|
# |15|Pará|
# |16|Amapá|
# |17|Tocantins|
# |21|Maranhão|
# |22|Piauí|
# |23|Ceará|
# |24|Rio Grande do Norte|
# |25|Paraíba|
# |26|Pernambuco|
# |27|Alagoas|
# |28|Sergipe|
# |29|Bahia|
# |31|Minas Gerais|
# |32|Espírito Santo|
# |33|Rio de Janeiro|
# |35|São Paulo|
# |41|Paraná|
# |42|Santa Catarina|
# |43|Rio Grande do Sul|
# |50|Mato Grosso do Sul|
# |51|Mato Grosso|
# |52|Goiás|
# |53|Distrito Federal|
#
# > ### Sexo
# > ***
#
# |Código|Descrição|
# |---|---|
# |0|Masculino|
# |1|Feminino|
#
# > ### Anos de Estudo
# > ***
#
# |Código|Descrição|
# |---|---|
# |1|Sem instrução e menos de 1 ano|
# |2|1 ano|
# |3|2 anos|
# |4|3 anos|
# |5|4 anos|
# |6|5 anos|
# |7|6 anos|
# |8|7 anos|
# |9|8 anos|
# |10|9 anos|
# |11|10 anos|
# |12|11 anos|
# |13|12 anos|
# |14|13 anos|
# |15|14 anos|
# |16|15 anos ou mais|
# |17|Não determinados|
# ||Não aplicável|
#
# > ### Cor
# > ***
#
# |Código|Descrição|
# |---|---|
# |0|Indígena|
# |2|Branca|
# |4|Preta|
# |6|Amarela|
# |8|Parda|
# |9|Sem declaração|

# %% [markdown]
# #### <font color='red'>Observação</font>
# ***
# > Os seguintes tratamentos foram realizados nos dados originais:
# > 1. Foram eliminados os registros onde a <b>Renda</b> era inválida (999 999 999 999);
# > 2. Foram eliminados os registros onde a <b>Renda</b> era missing;
# > 3. Foram considerados somente os registros das <b>Pessoas de Referência</b> de cada domicílio (responsável pelo domicílio).

# %% [markdown]
# ### Importando pandas e lendo o dataset do projeto
#
# https://pandas.pydata.org/

# %%
dados = pd.read_csv('dados.csv')
dados.head()
# Out:
#    UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0  11     0     23    8              12    800  1.603808
# 1  11     1     23    2              12   1150  1.739790
# 2  11     1     35    8              15    880  1.760444
# 3  11     0     46    2               6   3500  1.783158
# 4  11     1     47    8               9    150  1.690631

# %% [markdown]
# ## <font color=green>1.2 Tipos de dados</font>
# ***

# %% [markdown]
# ### Variáveis qualitativas ordinais
#
# ► Variáveis que podem ser ordenadas ou hierarquizardas
#
# Variáveis qualitativas ordinais são aquelas que representam atributos ou qualidades que podem ser ordenadas ou hierarquizadas. A principal característica é que, apesar de não serem numéricas em sua essência, existe uma ordem lógica entre as categorias.
#
# Dica: Pense em outras situações do dia a dia que podem ser ordenadas, como níveis de escolaridade, estágios de uma doença (leve, moderado, grave) ou classificações de um produto (ruim, bom, excelente).

# %%
sorted(dados['Anos de Estudo'].unique())
# Out:
# [np.int64(1),
#  np.int64(2),
#  np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(8),
#  np.int64(9),
#  np.int64(10),
#  np.int64(11),
#  np.int64(12),
#  np.int64(13),
#  np.int64(14),
#  np.int64(15),
#  np.int64(16),
#  np.int64(17)]

# %% [markdown]
# ### Variáveis qualitativas nominais
#
# ► Variáveis que não podem ser ordenadas ou hierarquizardas
# Variáveis qualitativas nominais representam atributos ou qualidades que não podem ser ordenadas. ou seja, as categorias são apenas nomes que servem para classificar os dados, sem nenhuma hierarquia entre elas.
# Lembre-se A característica principal é que as categorias são distintas e não podem er organizadas em uma ordem especifica

# %%
sorted(dados['UF'].unique())
# Out:
# [np.int64(11),
#  np.int64(12),
#  np.int64(13),
#  np.int64(14),
#  np.int64(15),
#  np.int64(16),
#  np.int64(17),
#  np.int64(21),
#  np.int64(22),
#  np.int64(23),
#  np.int64(24),
#  np.int64(25),
#  np.int64(26),
#  np.int64(27),
#  np.int64(28),
#  np.int64(29),
#  np.int64(31),
#  np.int64(32),
#  np.int64(33),
#  np.int64(35),
#  np.int64(41),
#  np.int64(42),
#  np.int64(43),
#  np.int64(50),
#  np.int64(51),
#  np.int64(52),
#  np.int64(53)]

# %%
sorted(dados['Sexo'].unique())
# Out:
# [np.int64(0), np.int64(1)]

# %%
sorted(dados['Cor'].unique())
# Out:
# [np.int64(0), np.int64(2), np.int64(4), np.int64(6), np.int64(8)]

# %% [markdown]
# ### Variáveis quantitativas discretas
#
# Variáveis que representam uma contagem onde os valores possíveis formam um conjunto finito ou enumerável.

# %%
dados.Idade.max()
# Out:
# np.int64(99)

# %% [markdown]
# #### <font color='red'>Observação</font>
# ***
# > A variável idade pode ser classificada de três formas distintas:
# > 1. <b>QUANTITATIVA DISCRETA</b> - quando representa anos completos (números inteiros);
# > 2. <b>QUANTITATIVA CONTÍNUA</b> - quando representa a idade exata, sendo representado por frações de anos; e
# > 3. <b>QUALITATIVA ORDINAL</b> - quando representa faixas de idade.

# %% [markdown]
# ### Variáveis quantitativas contínuas
#
# - Variáveis que representam uma contagem ou mensuração que assumem valores em uma escala contínua (números reais).
# - Variáveis quantitativas contínuas são aquelas que podem assumir qualquer valor dentro de um intervalo, incluindo valores decimais.

# %%
sorted(dados['Altura'].unique())
# Out:
# [np.float64(1.339244614),
#  np.float64(1.369493509),
#  np.float64(1.382390375),
#  np.float64(1.522268637),
#  np.float64(1.52230798),
#  np.float64(1.522373422),
#  np.float64(1.522387289),
#  np.float64(1.522420009),
#  np.float64(1.522433453),
#  np.float64(1.522446885),
#  np.float64(1.522447935),
#  np.float64(1.522449627),
#  np.float64(1.52247641),
#  np.float64(1.522527218),
#  np.float64(1.522568973),
#  np.float64(1.522577025),
#  np.float64(1.522584188),
#  np.float64(1.522633722),
#  np.float64(1.522644429),
#  np.float64(1.522668364),
#  np.float64(1.522681949),
#  np.float64(1.522732374),
#  np.float64(1.522746461),
#  np.float64(1.522773208),
#  np.float64(1.522807524),
#  np.float64(1.522862974),
#  np.float64(1.522880558),
#  np.float64(1.522887633),
#  np.float64(1.522891822),
#  np.float64(1.522892572),
#  np.float64(1.522954239),
#  np.float64(1.522962739),
#  np.float64(1.523025896),
#  np.float64(1.523028999),
#  np.float64(1.523031327),
#  np.float64(1.523079799),
#  np.float64(1.523101196),
#  np.float64(1.523110283),
#  np.float64(1.523131654),
#  np.float64(1.523210201),
#  np.float64(1.523216378),
#  np.float64(1.523233133),
#  np.float64(1.523244206),
#  np.float64(1.523266819),
#  np.float64(1.523275193),
#  ...]

# %% [markdown]
# ### Classificação de uma variável
# <img src='https://caelum-online-public.s3.amazonaws.com/1177-estatistica-parte1/01/img001.png' width='70%'>

# %% [markdown]
# # <font color=green>2 DISTRIBUIÇÃO DE FREQUÊNCIAS</font>
# ***
#
# O primeiro passo em um trabalho de análise é o conhecimento do comportamento das variáveis envolvidas no estudo. Utilizando técnicas estatísticas como as análises das <b>DISTRIBUIÇÕES DE FREQUÊNCIAS</b> e <b>HISTOGRAMAS</b> podemos avaliar melhor a forma como os fenômenos em estudo se distribuem.

# %% [markdown]
# ## <font color=green>2.1 Distribuição de frequências para variáveis qualitativas</font>
# ***

# %% [markdown]
# ### Método 1

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.Series.value_counts.html

# %% [markdown]
# ### Método 2

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.crosstab.html

# %% [markdown]
# ## <font color=green>2.2 Distribuição de frequências para variáveis quantitativas (classes personalizadas)</font>
# ***

# %% [markdown]
# ### Passo 1 - Especificar os limites de cada classe
#
# Utilizar a seguinte classificação:
#
# <b>A</b> ► Acima de 20 SM
#
# <b>B</b> ► De 10 a 20 SM
#
# <b>C</b> ► De 4 a 10 SM
#
# <b>D</b> ► De 2 a 4 SM
#
# <b>E</b> ► Até 2 SM
#
# onde <b>SM</b> é o valor do salário mínimo na época. Em nosso caso <b>R$ 788,00</b> (2015):
#
# <b>A</b> ► Acima de 15.760
#
# <b>B</b> ► De 7.880 a 15.760
#
# <b>C</b> ► De 3.152 a 7.880
#
# <b>D</b> ► De 1.576 a 3.152
#
# <b>E</b> ► Até 1.576

# %% [markdown]
# ### Passo 2 - Criar a tabela de frequências

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.cut.html

# %% [markdown]
# ## <font color=green>2.3 Distribuição de frequências para variáveis quantitativas (classes de amplitude fixa)</font>
# ***

# %% [markdown]
# ### Importando bibliotecas
#
# http://www.numpy.org/

# %% [markdown]
# ### Passo 1 - Difinindo o número de classes

# %% [markdown]
# #### Regra de Sturges
#
# # $$k = 1 + \frac {10}{3}\log_{10}n$$

# %% [markdown]
# ### Passo 2 - Criar a tabela de frequências

# %% [markdown]
# ## <font color=green>2.4 Histograma</font>
# ***
#
# O <b>HISTOGRAMA</b> é a representação gráfica de uma distribuição de frequências. É uma gráfico formado por um conjunto de retângulos colocados lado a lado, onde a área de cada retângulo é proporcional à frequência da classe que ele representa.

# %% [markdown]
# ### Importando a biblioteca
#
# https://seaborn.pydata.org/

# %% [markdown]
# # <font color=green>3 MEDIDAS DE TENDÊNCIA CENTRAL</font>
# ***

# %% [markdown]
# ## DataFrame de exemplo

# %% [markdown]
# ## <font color=green>3.1 Média aritmética</font>
# ***
#
# É representada por $\mu$ quando se refere à população e por $\bar{X}$ quando se refere à amostra
#
# # $$\mu = \frac 1n\sum_{i=1}^{n}X_i$$
#
# onde
#
# $n$ = número de observações (registros)
#
# $X_i$ = valor da i-ésima observação (registro)

# %% [markdown]
# ## <font color=green>3.2 Mediana</font>
# ***
#
# Para obtermos a mediana de uma conjunto de dados devemos proceder da seguinte maneira:
# 1. Ordenar o conjunto de dados;
# 2. Identificar o número de observações (registros) do conjunto de dados ($n$);
# 3. Identicar o elemento mediano:
#
# > Quando $n$ for ímpar, a posição do elemento mediano será obtida da seguinte forma:
#
#
# # $$Elemento_{Md} = \frac{n+1}2$$
#
# > Quando $n$ for par, a posição do elemento mediano será obtida da seguinte forma:
#
#
# # $$Elemento_{Md} = \frac{n}2$$
#
# 4. Obter a mediana:
#
# > Quando $n$ for ímpar:
#
#
# # $$Md = X_{Elemento_{Md}}$$
#
# > Quando $n$ for par:
#
#
# # $$Md = \frac{X_{Elemento_{Md}} + X_{Elemento_{Md}+1}}2$$
# ***

# %% [markdown]
# ### Exemplo 1 - n ímpar
#
# <img src='https://caelum-online-public.s3.amazonaws.com/1177-estatistica-parte1/01/img002.png' width='40%' style="float:left">

# %% [markdown]
# ### Exemplo 2 - n par
#
# <img src='https://caelum-online-public.s3.amazonaws.com/1177-estatistica-parte1/01/img003.png' width='50%' style="float:left">

# %% [markdown]
# ### Obtendo a mediana em nosso dataset

# %% [markdown]
# ## <font color=green>3.3 Moda</font>
# ***
#
# Pode-se definir a moda como sendo o valor mais frequente de um conjunto de dados. A moda é bastante utilizada para dados qualitativos.

# %% [markdown]
# ### Obtendo a moda em nosso dataset

# %% [markdown]
# ## <font color=green>3.4 Relação entre média, mediana e moda</font>
# ***

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1177-estatistica-parte1/01/img004.png' width='80%'>

# %% [markdown]
# ### Avaliando a variável RENDA

# %% [markdown]
# ***

# %% [markdown]
# ### Avaliando a variável ALTURA

# %% [markdown]
# ***

# %% [markdown]
# ### Avaliando a variável ANOS DE ESTUDO

# %% [markdown]
# # <font color=green>4 MEDIDAS SEPARATRIZES</font>
# ***

# %% [markdown]
# ## <font color=green>4.1 Quartis, decis e percentis</font>
# ***
#
# Há uma série de medidas de posição semelhantes na sua concepção à mediana, embora não sejam medidas de tendência central. Como se sabe, a mediana divide a distribuição em duas partes iguais quanto ao número de elementos de cada parte. Já os quartis permitem dividir a distribuição em quatro partes iguais quanto ao número de elementos de cada uma; os decis em dez partes e os centis em cem partes iguais.

# %% [markdown]
# ## <font color=green>4.2 Box-plot</font>
# ***
#
# O box plot dá uma idéia da posição, dispersão, assimetria, caudas e dados discrepantes (outliers). A posição central é dada pela mediana e a dispersão por $IIQ$. As posições relativas de $Q1$, $Mediana$ e $Q3$ dão uma noção da simetria da distribuição. Os comprimentos das cauda são dados pelas linhas que vão do retângulo aos valores remotos e pelos valores atípicos.

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1177-estatistica-parte1/01/img005.png' width='65%'>

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1177-estatistica-parte1/01/img006.png' width='80%'>

# %% [markdown]
# # <font color=green>5 MEDIDAS DE DISPERSÃO</font>
# ***
#
# Embora as medidas de posição forneçam uma sumarização bastante importante dos dados, elas podem não ser suficientes para caracterizar conjuntos distintos, especialmente quando as observações de determinada distribuição apresentarem dados muito dispersos.

# %% [markdown]
# ## <font color=green>5.1 Desvio médio absoluto</font>
# ***
#
#
# # $$DM = \frac 1n\sum_{i=1}^{n}|X_i-\bar{X}|$$

# %% [markdown]
# ## <font color=green>5.2 Variância</font>
# ***

# %% [markdown]
# ### Variância
#
# A variância é construída a partir das diferenças entre cada observação e a média dos dados, ou seja, o desvio em torno da média. No cálculo da variância, os desvios em torno da média são elevados ao quadrado.

# %% [markdown]
# ### Variância populacional
#
# # $$\sigma^2 = \frac 1n\sum_{i=1}^{n}(X_i-\mu)^2$$

# %% [markdown]
# ### Variância amostral
#
# # $$S^2 = \frac 1{n-1}\sum_{i=1}^{n}(X_i-\bar{X})^2$$

# %% [markdown]
# ## <font color=green>5.3 Desvio padrão</font>
# ***
#
# Uma das restrições da variância é o fato de fornecer medidas em quadrados das unidades originais - a variância de medidas de comprimento, por exemplo, é em unidades de área. Logo, o fato de as unidades serem diferentes dificulta a comparação da dispersão com as variáveis que a definem. Um modo de eliminar essa dificuldade é considerar sua raiz quadrada.

# %% [markdown]
# ### Desvio padrão populacional
#
# # $$\sigma = \sqrt{\frac 1n\sum_{i=1}^{n}(X_i-\mu)^2} \Longrightarrow \sigma = \sqrt{\sigma^2}$$

# %% [markdown]
# ### Desvio padrão amostral
#
# # $$S = \sqrt{\frac 1{n-1}\sum_{i=1}^{n}(X_i-\bar{X})^2} \Longrightarrow S = \sqrt{S^2}$$
